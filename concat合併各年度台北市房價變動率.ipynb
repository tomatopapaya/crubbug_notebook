# %%
import pandas as pd

# %%
df1=pd.read_csv('C://Users//ASUS//Desktop//我的專題報告//106年房價比.csv',encoding='utf-8')

# %%
df2=pd.read_csv('C://Users//ASUS//Desktop//我的專題報告//107年房價比.csv',encoding='utf-8')

# %%
df3=pd.read_csv('C://Users//ASUS//Desktop//我的專題報告//108年房價比.csv',encoding='utf-8')

# %%
df4=pd.read_csv('C://Users//ASUS//Desktop//我的專題報告//109年房價比.csv',encoding='utf-8')

# %%
df5=pd.read_csv('C://Users//ASUS//Desktop//我的專題報告//110年房價比.csv',encoding='utf-8')

# %%
df11=pd.concat([df1,df2,df3,df4,df5])
df11
# Out:
#     Unnamed: 0    年分   縣市  房貸負擔率(%) 房貸負擔率(百分點)季變動值  房貸負擔率(百分點)年變動值  房價所得比(倍)  \
# 0            0  2017   全國     38.90           0.86            1.76      9.46
# 1            1  2017  臺北市     64.29           0.39            1.90     15.64
# 2            2  2017  新北市     52.19           0.74            0.38     12.70
# 3            3  2017  臺中市     39.60            1.0            0.92      9.63
# 4            4  2017  新竹市     36.14           -0.4            3.71      8.79
# ..         ...   ...  ...       ...            ...             ...       ...
# 16          16  2021  花蓮縣     33.96           0.39            2.84      8.50
# 17          17  2021  澎湖縣     33.30           -3.8            5.38      8.33
# 18          18  2021  基隆市     22.80          -0.06           -0.14      5.70
# 19          19  2021  新竹市     29.66           0.97            2.61      7.42
# 20          20  2021  嘉義市     22.71          -0.03            3.18      5.68
#
#     房價所得比(倍)季變動值  房價所得比(倍)年變動值
# ...

# %%
df11.to_csv('各年度縣市房價比.csv',encoding='utf-8-sig')

# %%
df11
# Out:
#     Unnamed: 0    年分   縣市  房貸負擔率(%) 房貸負擔率(百分點)季變動值  房貸負擔率(百分點)年變動值  房價所得比(倍)  \
# 0            0  2017   全國     38.90           0.86            1.76      9.46
# 1            1  2017  臺北市     64.29           0.39            1.90     15.64
# 2            2  2017  新北市     52.19           0.74            0.38     12.70
# 3            3  2017  臺中市     39.60            1.0            0.92      9.63
# 4            4  2017  新竹市     36.14           -0.4            3.71      8.79
# ..         ...   ...  ...       ...            ...             ...       ...
# 16          16  2021  花蓮縣     33.96           0.39            2.84      8.50
# 17          17  2021  澎湖縣     33.30           -3.8            5.38      8.33
# 18          18  2021  基隆市     22.80          -0.06           -0.14      5.70
# 19          19  2021  新竹市     29.66           0.97            2.61      7.42
# 20          20  2021  嘉義市     22.71          -0.03            3.18      5.68
#
#     房價所得比(倍)季變動值  房價所得比(倍)年變動值
# ...

# %%
print(df11[df11["縣市"].isin(["臺北市"])])
# Out:
#    Unnamed: 0    年分   縣市  房貸負擔率(%) 房貸負擔率(百分點)季變動值  房貸負擔率(百分點)年變動值  房價所得比(倍)  \
# 1           1  2017  臺北市     64.29           0.39            1.90     15.64
# 1           1  2018  臺北市     61.56           0.02           -2.72     15.01
# 2           2  2019  臺北市     59.25           1.18           -2.31     14.45
# 2           2  2020  臺北市     57.57           0.51           -1.68     14.39
# 2           2  2021  臺北市     63.11           0.94            5.54     15.79
#
#    房價所得比(倍)季變動值  房價所得比(倍)年變動值
# 1          0.12          0.57
# 1          0.01         -0.63
# 2          0.30         -0.56
# 2          0.45         -0.06
# 2          0.25          1.40
