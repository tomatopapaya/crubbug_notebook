# %%
import requests

# %%
import mytool

# %%
from bs4 import BeautifulSoup

# %%
from mytool import get_soup

# %%
url="http://app2.atmovies.com.tw/boxoffice/worldwide/2021-10-03/more/"

# %%
soup=get_soup(url)
soup
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <title>開眼電影網--新版--</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--[if lte IE 8]><script src="/assets/js/ie/html5shiv.js"></script><![endif]-->
# <link href="/assets/css/main-2.css?20160606" rel="stylesheet"/>
# <!--[if lte IE 8]><link rel="stylesheet" href="/assets/css/ie8.css" /><![endif]-->
# <!-- jAMES + -->
# <link href="/assets/icons/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- Scripts -->
# <script src="/assets/js/jquery.min.js"></script>
# <script src="/assets/js/jquery.dropotron.min.js"></script>
# <script src="/assets/js/skel.min.js"></script>
# <script src="/assets/js/skel-viewport.min.js"></script>
# <script src="/assets/js/util.js"></script>
# <!--[if lte IE 8]><script src="assets/js/ie/respond.min.js"></script><![endif]-->
# <script src="/assets/js/main.js"></script>
# <!-- jAMES + -->
# <script src="/assets/js/home.js?v=101"></script>
# ...

# %%
tr=soup.find('tbody')
tr
